# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

#Uppgift A)

college = pd.read_csv("../Data/College.csv")

# %%
# Uppgift B)

college2 = pd.read_csv("../Data/College.csv", index_col=0)
college2.head()
# Out:
#                              Private  Apps  Accept  Enroll  Top10perc  \
# Abilene Christian University     Yes  1660    1232     721         23
# Adelphi University               Yes  2186    1924     512         16
# Adrian College                   Yes  1428    1097     336         22
# Agnes Scott College              Yes   417     349     137         60
# Alaska Pacific University        Yes   193     146      55         16
#
#                               Top25perc  F.Undergrad  P.Undergrad  Outstate  \
# Abilene Christian University         52         2885          537      7440
# Adelphi University                   29         2683         1227     12280
# Adrian College                       50         1036           99     11250
# Agnes Scott College                  89          510           63     12960
# Alaska Pacific University            44          249          869      7560
#
#                               Room.Board  Books  Personal  PhD  Terminal  \
# ...

# %%
# Uppgift B)


college3 = college.rename({"Unnamed: 0" : "College"}, axis=1)
college3 = college3.set_index("College")
college = college3
college.head()
# Out:
#                              Private  Apps  Accept  Enroll  Top10perc  \
# College
# Abilene Christian University     Yes  1660    1232     721         23
# Adelphi University               Yes  2186    1924     512         16
# Adrian College                   Yes  1428    1097     336         22
# Agnes Scott College              Yes   417     349     137         60
# Alaska Pacific University        Yes   193     146      55         16
#
#                               Top25perc  F.Undergrad  P.Undergrad  Outstate  \
# College
# Abilene Christian University         52         2885          537      7440
# Adelphi University                   29         2683         1227     12280
# Adrian College                       50         1036           99     11250
# Agnes Scott College                  89          510           63     12960
# Alaska Pacific University            44          249          869      7560
#
# ...

# %%
#Uppgift C)

college.describe()
# Out:
#                Apps        Accept       Enroll   Top10perc   Top25perc  \
# count    777.000000    777.000000   777.000000  777.000000  777.000000
# mean    3001.638353   2018.804376   779.972973   27.558559   55.796654
# std     3870.201484   2451.113971   929.176190   17.640364   19.804778
# min       81.000000     72.000000    35.000000    1.000000    9.000000
# 25%      776.000000    604.000000   242.000000   15.000000   41.000000
# 50%     1558.000000   1110.000000   434.000000   23.000000   54.000000
# 75%     3624.000000   2424.000000   902.000000   35.000000   69.000000
# max    48094.000000  26330.000000  6392.000000   96.000000  100.000000
#
#         F.Undergrad   P.Undergrad      Outstate   Room.Board        Books  \
# count    777.000000    777.000000    777.000000   777.000000   777.000000
# mean    3699.907336    855.298584  10440.669241  4357.526384   549.380952
# std     4850.420531   1522.431887   4023.016484  1096.696416   165.105360
# ...

# %%
#Uppgift D)

pd.plotting.scatter_matrix(college[["Top10perc", "Apps", "Enroll"]])
# Out:
# array([[<Axes: xlabel='Top10perc', ylabel='Top10perc'>,
#         <Axes: xlabel='Apps', ylabel='Top10perc'>,
#         <Axes: xlabel='Enroll', ylabel='Top10perc'>],
#        [<Axes: xlabel='Top10perc', ylabel='Apps'>,
#         <Axes: xlabel='Apps', ylabel='Apps'>,
#         <Axes: xlabel='Enroll', ylabel='Apps'>],
#        [<Axes: xlabel='Top10perc', ylabel='Enroll'>,
#         <Axes: xlabel='Apps', ylabel='Enroll'>,
#         <Axes: xlabel='Enroll', ylabel='Enroll'>]], dtype=object)

# %%
#Uppgift E)

college.boxplot("Outstate", "Private")
# Out:
# <Axes: title={'center': 'Outstate'}, xlabel='Private'>

# %%
# Uppgift F)

college["Elite"]= pd.cut(college["Top10perc"], [0,50,100], labels=["No", "Yes"])
college.boxplot("Outstate","Elite")
# Out:
# <Axes: title={'center': 'Outstate'}, xlabel='Elite'>

# %%
#Uppgift G)

fig, axes = plt.subplots(2,2, figsize=(16,5))
college["Apps"].plot.hist(bins=30, ax=axes[0,0],color="blue",title="Application (bins=30)")
college["Accept"].plot.hist(bins=50, ax=axes[0,1],color="yellow",title="Accepted (bins=50)")
college["Books"].plot.hist(bins=60, ax=axes[1,0], color="Green", title="Cost of books (bins=60)")
college["Grad.Rate"].plot.hist(bins=70, ax=axes[1,1],color="orange",title="Graduation rate (bins=70)")
plt.tight_layout()
plt.show()

# %%
# Uppgift H)

college_numeric = college.select_dtypes(include="number")
corr_matrix = college_numeric.corr()
#corr_matrix= corr_matrix[corr_matrix > 0.5]
sns.heatmap(corr_matrix, linewidths=0.07, linecolor="black", cmap="coolwarm")
plt.title("Heatmap over correlation")
plt.show()

# %% [markdown]
# #### I "heatmapen" ovan så ser vi olika korrelationer i vår data som jag undersöker och förklarar mer här nedan.

# %%
fig, axes = plt.subplots(1,3 ,figsize=(15,5))
fig.suptitle("Acceptance into school")
sns.regplot(data=college, x="Apps", y="Accept", ax=axes[0])
sns.regplot(data=college, x="Accept", y="Enroll", ax=axes[1])
sns.regplot(data=college, x="Enroll", y="F.Undergrad", ax=axes[2])
axes[0].set_title("Application vs Accept")
axes[1].set_title("Accept vs Enroll")
axes[2].set_title("Enroll vs Fulltime Undergrad")
plt.tight_layout()

# %% [markdown]
# #### Antagning
# Ju fler studenter som söker en utbildning desto fler studenter blir accepterade och påbörjar en utbildning. En anledning till detta kan vara att skolorna ej har nått sitt maxtak på antalet studenter man kan ta emot. Min teori är att det handlar snarare om att man har möjligheten att ta in studenter än att skolorna är selektiva, då korrelationen mellan dessa punkter förmodligen varit mindre än vad den är i detta fall.

# %%
fig, axes = plt.subplots(1,3 ,figsize=(15,5))
plt.suptitle("Top students choice of school")
sns.regplot(data=college, x="Top10perc", y="Top25perc", ax=axes[0])
sns.regplot(data=college, x="Top10perc", y="Expend", ax=axes[1])
sns.regplot(data=college, x="Top10perc", y="PhD", ax=axes[2])
axes[0].set_title("Top 10% and Top 25% ")
axes[1].set_title("Top 10% and Expenditure")
axes[2].set_title("Top 10% and PhD faculty")
plt.tight_layout()

# %% [markdown]
# #### Starka akademiska studenter
# För studenter som varit bland de 10% och 25% bäst presterande i sin gymnasieutbildning (highschool klass) så ser vi en korrelation med att dem väljer skolor som både har fler fakulteter med en doktorexamen samt skolor som spenderar mer pengar på sina elevers lärande. Man kan anta att av denna data att studenter som är akademiskt starka är mer selektiva med val av skola då dom kan vara det pågrund av sina tidigare prestationer akademiskt. Valet av en prestigefylld akademiskt stark skola lockar i sin tur fler top-presterande studenter till skolan och likt en positiv spiral stärker skolans rykte ytterligare för framtida topstudenter.

# %% [markdown]
# #### Avslutande ord
# Resultaten som framkommit är min tolkning av korrelationen i datan. Mönstret i statistiken är en stark indikator på hur datan kan tolkas men eftersom jag inte formulerat någon hypotes innan så är min analys helt explorativ.
